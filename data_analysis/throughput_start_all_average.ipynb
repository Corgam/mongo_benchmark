# %%
"""
Notebook usage: 

Plots:
    1. Average throughput for all sharding scenarios from all experiments. (for the slow start data)
    2. Average throughput for 2 and 3 shards scenarios from all experiments. (for the slow start data)

Setup:
    In order to run, change the DATA_PATHS to corresponding files.
    Additionally, for all files, the starting time needs to be subtracted from each data record, for example:
    with start: 2022-02-06 14:14:20.868178 the line should be:
    df_responses2_1["time"] = df_responses2_1["time"].apply(lambda x: x-datetime.datetime(2022, 2, 6,14,14,20,868178))

Note: it is not guaranteed that the plotting will work for new data. Some of the variables where changed by hand,
 and need to be changed again when new data is plotted.
"""
# %matplotlib widget
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
import numpy as np
DATA_PATH0_1 = "Results_benchmark_start1\Sorted_Results11_Shards1_07-02-2022_16-52-42.txt.csv"
DATA_PATH0_2 = "Results_benchmark_start2\Sorted_Results14_Shards1_07-02-2022_20-26-38.txt.csv"
DATA_PATH0_3 = "Results_benchmark_start3\Sorted_Results17_Shards1_08-02-2022_00-48-03.txt.csv"

DATA_PATH2_1 = "Results_benchmark_start1\Sorted_Results9_Shards2_07-02-2022_13-42-32.txt.csv"
DATA_PATH2_2 = "Results_benchmark_start2\Sorted_Results12_Shards2_07-02-2022_18-42-53.txt.csv"
DATA_PATH2_3 = "Results_benchmark_start3\Sorted_Results15_Shards2_07-02-2022_23-07-49.txt.csv"

DATA_PATH3_1 = "Results_benchmark_start1\Sorted_Results10_Shards3_07-02-2022_14-58-06.txt.csv"
DATA_PATH3_2 = "Results_benchmark_start2\Sorted_Results13_Shards3_07-02-2022_19-39-33.txt.csv"
DATA_PATH3_3 = "Results_benchmark_start3\Sorted_Results16_Shards3_07-02-2022_23-52-46.txt.csv"

# %%
# 2 Shards

df2_1: pd.DataFrame = pd.DataFrame()
df2_1: pd.DataFrame = pd.read_csv(DATA_PATH2_1)
df_responses2_1 = df2_1[df2_1.action == "ReceivedResponse"]
df_responses2_1 = df_responses2_1[["time","latency"]]
df_responses2_1["time"] = pd.to_datetime(df_responses2_1["time"])
# Start: 2022-02-07 12:21:58.992316
df_responses2_1["time"] = df_responses2_1["time"].apply(lambda x: x-datetime.datetime(2022,2,7,12,22,0,280530))
df_responses2_1 = df_responses2_1.set_index("time")
seconds2_1 = df_responses2_1.latency.resample("S").count()
seconds2_1 = seconds2_1.rolling(50).mean()
print(seconds2_1.mean())
print(seconds2_1.head(10))
ax = seconds2_1.plot(label="No Shards")
ax.plot()

df2_2: pd.DataFrame = pd.DataFrame()
df2_2: pd.DataFrame = pd.read_csv(DATA_PATH2_2)
df_responses2_2 = df2_2[df2_2.action == "ReceivedResponse"]
df_responses2_2 = df_responses2_2[["time","latency"]]
df_responses2_2["time"] = pd.to_datetime(df_responses2_2["time"])
# Start: 2022-02-07 17:22:18.911832
df_responses2_2["time"] = df_responses2_2["time"].apply(lambda x: x-datetime.datetime(2022,2,7,17,22,20,257100))
df_responses2_2 = df_responses2_2.set_index("time")
seconds2_2 = df_responses2_2.latency.resample("S").count()
seconds2_2 = seconds2_2.rolling(50).mean()
print(seconds2_2.mean())
print(seconds2_2.head(10))
ax2 = seconds2_2.plot(label="No Shards")
ax2.plot()

df2_3: pd.DataFrame = pd.DataFrame()
df2_3: pd.DataFrame = pd.read_csv(DATA_PATH2_3)
df_responses2_3 = df2_3[df2_3.action == "ReceivedResponse"]
df_responses2_3 = df_responses2_3[["time","latency"]]
df_responses2_3["time"] = pd.to_datetime(df_responses2_3["time"])
# Start: 2022-02-07 21:47:15.958777
df_responses2_3["time"] = df_responses2_3["time"].apply(lambda x: x-datetime.datetime(2022,2,7,21,47,17,312538))
df_responses2_3 = df_responses2_3.set_index("time")
seconds2_3 = df_responses2_3.latency.resample("S").count()
seconds2_3 = seconds2_3.rolling(50).mean()
print(seconds2_3.mean())
print(seconds2_3.head(10))
ax3 = seconds2_3.plot(label="No Shards")
ax3.plot()
# Out:
# 1348.862992392223
# time
# 0 days 00:00:00   NaN
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# Freq: S, Name: latency, dtype: float64
# 1535.757345731192
# time
# 0 days 00:00:00   NaN
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# Freq: S, Name: latency, dtype: float64
# 1406.5974978867284
# time
# 0 days 00:00:00   NaN
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# Freq: S, Name: latency, dtype: float64
# []
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 3 Shards
plt.clf()
df3_1: pd.DataFrame = pd.DataFrame()
df3_1: pd.DataFrame = pd.read_csv(DATA_PATH3_1)
df_responses3_1 = df3_1[df3_1.action == "ReceivedResponse"]
df_responses3_1 = df_responses3_1[["time","latency"]]
df_responses3_1["time"] = pd.to_datetime(df_responses3_1["time"])
# Start: 2022-02-07 13:37:32.811808
df_responses3_1["time"] = df_responses3_1["time"].apply(lambda x: x-datetime.datetime(2022,2,7,13,37,34,85351))
df_responses3_1 = df_responses3_1.set_index("time")
seconds3_1 = df_responses3_1.latency.resample("S").count()
seconds3_1 = seconds3_1.rolling(50).mean()
print(seconds3_1.mean())
print(seconds3_1.head(10))
ax = seconds3_1.plot(label="No Shards")
ax.plot()

df3_2: pd.DataFrame = pd.DataFrame()
df3_2: pd.DataFrame = pd.read_csv(DATA_PATH3_2)
df_responses3_2 = df3_2[df3_2.action == "ReceivedResponse"]
df_responses3_2 = df_responses3_2[["time","latency"]]
df_responses3_2["time"] = pd.to_datetime(df_responses3_2["time"])
# Start: 2022-02-07 18:18:58.777441
df_responses3_2["time"] = df_responses3_2["time"].apply(lambda x: x-datetime.datetime(2022,2,7,18,18,58,777441 + 200049 ))
df_responses3_2 = df_responses3_2.set_index("time")
seconds3_2 = df_responses3_2.latency.resample("S").count()
seconds3_2 = seconds3_2.rolling(50).mean()
print(seconds3_2.mean())
print(seconds3_2.head(10))
ax2 = seconds3_2.plot(label="No Shards")
ax2.plot()

df3_3: pd.DataFrame = pd.DataFrame()
df3_3: pd.DataFrame = pd.read_csv(DATA_PATH3_3)
df_responses3_3 = df3_3[df3_3.action == "ReceivedResponse"]
df_responses3_3 = df_responses3_3[["time","latency"]]
df_responses3_3["time"] = pd.to_datetime(df_responses3_3["time"])
# Start: 2022-02-07 22:32:12.582604
df_responses3_3["time"] = df_responses3_3["time"].apply(lambda x: x-datetime.datetime(2022,2,7,22,32,12,582604 + 205450))
df_responses3_3 = df_responses3_3.set_index("time")
seconds3_3 = df_responses3_3.latency.resample("S").count()
seconds3_3 = seconds3_3.rolling(50).mean()
print(seconds3_3.mean())
print(seconds3_3.head(10))
ax3 = seconds3_3.plot(label="No Shards")
ax3.plot()
# Out:
# 1459.926086221471
# time
# 0 days 00:00:00   NaN
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# Freq: S, Name: latency, dtype: float64
# 1508.0089771766695
# time
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# 0 days 00:00:10   NaN
# Freq: S, Name: latency, dtype: float64
# 1393.317886728656
# time
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# 0 days 00:00:10   NaN
# Freq: S, Name: latency, dtype: float64
# []
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 0 Shards
plt.clf()
df1_1: pd.DataFrame = pd.DataFrame()
df1_1: pd.DataFrame = pd.read_csv(DATA_PATH0_1)
df_responses1_1 = df1_1[df1_1.action == "ReceivedResponse"]
df_responses1_1 = df_responses1_1[["time","latency"]]
df_responses1_1["time"] = pd.to_datetime(df_responses1_1["time"])
# Start: 2022-02-07 15:32:08.071672
df_responses1_1["time"] = df_responses1_1["time"].apply(lambda x: x-datetime.datetime(2022,2,7,15,32,8,71672+247136))
df_responses1_1 = df_responses1_1.set_index("time")
seconds1_1 = df_responses1_1.latency.resample("S").count()
seconds1_1 = seconds1_1.rolling(50).mean()
print(seconds1_1.mean())
print(seconds1_1.head(10))
ax = seconds1_1.plot(label="No Shards")
ax.plot()

df1_2: pd.DataFrame = pd.DataFrame()
df1_2: pd.DataFrame = pd.read_csv(DATA_PATH0_2)
df_responses1_2 = df1_2[df1_2.action == "ReceivedResponse"]
df_responses1_2 = df_responses1_2[["time","latency"]]
df_responses1_2["time"] = pd.to_datetime(df_responses1_2["time"])
# Start: 2022-02-07 19:06:04.205036
df_responses1_2["time"] = df_responses1_2["time"].apply(lambda x: x-datetime.datetime(2022,2,7,19,6,4,205036+193809))
df_responses1_2 = df_responses1_2.set_index("time")
seconds1_2 = df_responses1_2.latency.resample("S").count()
seconds1_2 = seconds1_2.rolling(50).mean()
print(seconds1_2.mean())
print(seconds1_2.head(10))
ax2 = seconds1_2.plot(label="No Shards")
ax2.plot()

df1_3: pd.DataFrame = pd.DataFrame()
df1_3: pd.DataFrame = pd.read_csv(DATA_PATH0_3)
df_responses1_3 = df1_3[df1_3.action == "ReceivedResponse"]
df_responses1_3 = df_responses1_3[["time","latency"]]
df_responses1_3["time"] = pd.to_datetime(df_responses1_3["time"])
# Start: 2022-02-07 23:27:28.648336
df_responses1_3["time"] = df_responses1_3["time"].apply(lambda x: x-datetime.datetime(2022,2,7,23,27,28,648336+227275))
df_responses1_3 = df_responses1_3.set_index("time")
seconds1_3 = df_responses1_3.latency.resample("S").count()
seconds1_3 = seconds1_3.rolling(50).mean()
print(seconds1_3.mean())
print(seconds1_3.head(10))
ax3 = seconds1_3.plot(label="No Shards")
ax3.plot()
# Out:
# 5400.206272189349
# time
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# 0 days 00:00:10   NaN
# Freq: S, Name: latency, dtype: float64
# 5253.48630600169
# time
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# 0 days 00:00:10   NaN
# Freq: S, Name: latency, dtype: float64
# 5135.666999154692
# time
# 0 days 00:00:01   NaN
# 0 days 00:00:02   NaN
# 0 days 00:00:03   NaN
# 0 days 00:00:04   NaN
# 0 days 00:00:05   NaN
# 0 days 00:00:06   NaN
# 0 days 00:00:07   NaN
# 0 days 00:00:08   NaN
# 0 days 00:00:09   NaN
# 0 days 00:00:10   NaN
# Freq: S, Name: latency, dtype: float64
# []
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
Procudes a plot for 2 and 3 shards (average from 3 experiments)
"""
time = timedelta(0,1)
sec = []
val = []
dt = pd.DataFrame()
for i in range(600):
    sec.append(time)
    string: str = str(time)
    value1 = seconds2_1["0 days "+string]
    value2 = seconds2_2["0 days "+string]
    value3 = seconds2_3["0 days "+string]
    value = np.mean([value1 ,value2, value3])
    val.append(value)
    time = time + timedelta(0,1)
finalDF2 = pd.DataFrame(val, sec)

time = timedelta(0,1)
sec = []
val = []
dt = pd.DataFrame()
for i in range(600):
    sec.append(time)
    string: str = str(time)
    value1 = seconds3_1["0 days "+string]
    value2 = seconds3_2["0 days "+string]
    value3 = seconds3_3["0 days "+string]
    value = np.mean([value1 ,value2, value3])
    val.append(value)
    time = time + timedelta(0,1)
finalDF3 = pd.DataFrame(val, sec)

ax = finalDF2.plot(ylabel= "Requests per second (req/sec)", xlabel="Time (min)", title="Average Throughput (3 benchmark runs)")
finalDF3.plot(ax=ax)
plt.legend((["2 Shards", "3 Shards"]),loc='lower right')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
Procudes a plot for 2 and 3 shards (average from 3 experiments)
"""
time = timedelta(0,1)
sec = []
val = []
dt = pd.DataFrame()
for i in range(600):
    sec.append(time)
    string: str = str(time)
    value1 = seconds2_1["0 days "+string]
    value2 = seconds2_2["0 days "+string]
    value3 = seconds2_3["0 days "+string]
    value = np.mean([value1 ,value2, value3])
    val.append(value)
    time = time + timedelta(0,1)
finalDF2 = pd.DataFrame(val, sec)

time = timedelta(0,1)
sec = []
val = []
dt = pd.DataFrame()
for i in range(600):
    sec.append(time)
    string: str = str(time)
    value1 = seconds3_1["0 days "+string]
    value2 = seconds3_2["0 days "+string]
    value3 = seconds3_3["0 days "+string]
    value = np.mean([value1 ,value2, value3])
    val.append(value)
    time = time + timedelta(0,1)
finalDF3 = pd.DataFrame(val, sec)

time = timedelta(0,1)
sec = []
val = []
dt = pd.DataFrame()
for i in range(600):
    sec.append(time)
    string: str = str(time)
    value1 = seconds1_1["0 days "+string]
    value2 = seconds1_2["0 days "+string]
    value3 = seconds1_3["0 days "+string]
    value = np.mean([value1 ,value2, value3])
    val.append(value)
    time = time + timedelta(0,1)
finalDF1 = pd.DataFrame(val, sec)

ax = finalDF2.plot(ylabel= "Requests per second (req/sec)", xlabel="Time (min)", title="Average Throughput (3 benchmark runs) - Start of Benchmark")
finalDF3.plot(ax=ax)
finalDF1.plot(ax=ax)
plt.legend((["2 Shards", "3 Shards", "No Shards"]),loc='center right')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

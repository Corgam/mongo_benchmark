# %%
# %matplotlib widget
import pandas as pd
import matplotlib.pyplot as plt
from datetime import timedelta
import numpy as np
DATA_PATH0_1 = "Results_benchmarks1\Sorted_Results2_Shards1_06-02-2022_16-47-31.txt.csv"
DATA_PATH0_2 = "Results_benchmarks2\Sorted_Results5_Shards1_06-02-2022_18-48-31.txt.csv"
DATA_PATH0_3 = "Results_benchmarks3\Sorted_Results8_Shards1_06-02-2022_23-17-05.txt.csv"

DATA_PATH2_1 = "Results_benchmarks1\Sorted_Results0_Shards2_06-02-2022_15-27-23.txt.csv"
DATA_PATH2_2 = "Results_benchmarks2\Sorted_Results3_Shards2_06-02-2022_17-21-53.txt.csv"
DATA_PATH2_3 = "Results_benchmarks3\Sorted_Results6_Shards2_06-02-2022_22-04-01.txt.csv"

DATA_PATH3_1 = "Results_benchmarks1\Sorted_Results1_Shards3_06-02-2022_16-06-34.txt.csv"
DATA_PATH3_2 = "Results_benchmarks2\Sorted_Results4_Shards3_06-02-2022_18-09-59.txt.csv"
DATA_PATH3_3 = "Results_benchmarks3\Sorted_Results7_Shards3_06-02-2022_22-38-15.txt.csv"

MOVING_AVERAGE_N = 10000

# %%
### NO SHARDS
df_0_1: pd.DataFrame = pd.read_csv(DATA_PATH0_1)
df_0_1: pd.DataFrame = df_0_1[df_0_1.action == "ReceivedResponse"]
df_0_1: pd.DataFrame = df_0_1["latency"].apply(lambda x: x*0.001)
df_0_1.drop(df_0_1.tail(10).index, inplace = True)
df_0_1: pd.DataFrame  = df_0_1.rolling(MOVING_AVERAGE_N).mean()
df_0_1: pd.DataFrame = df_0_1.dropna()
# ax = df_0_1.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 1")

df_0_2: pd.DataFrame = pd.read_csv(DATA_PATH0_2)
df_0_2: pd.DataFrame = df_0_2[df_0_2.action == "ReceivedResponse"]
df_0_2: pd.DataFrame = df_0_2["latency"].apply(lambda x: x*0.001)
df_0_2.drop(df_0_2.tail(10).index, inplace = True)
df_0_2: pd.DataFrame  = df_0_2.rolling(MOVING_AVERAGE_N).mean()
df_0_2: pd.DataFrame = df_0_2.dropna()
# ax = df_0_2.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 2")

df_0_3: pd.DataFrame = pd.read_csv(DATA_PATH0_3)
df_0_3: pd.DataFrame = df_0_3[df_0_3.action == "ReceivedResponse"]
df_0_3: pd.DataFrame = df_0_3["latency"].apply(lambda x: x*0.001)
df_0_3.drop(df_0_3.tail(10).index, inplace = True)
df_0_3: pd.DataFrame  = df_0_3.rolling(MOVING_AVERAGE_N).mean()
df_0_3: pd.DataFrame = df_0_3.dropna()
# ax = df_0_3.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 3")
# Out:
# Finished benchmark run 1
# Finished benchmark run 2
# Finished benchmark run 3

# %%
### 2 SHARDS
df_2_1: pd.DataFrame = pd.read_csv(DATA_PATH2_1)
df_2_1: pd.DataFrame = df_2_1[df_2_1.action == "ReceivedResponse"]
df_2_1: pd.DataFrame = df_2_1["latency"].apply(lambda x: x*0.001)
df_2_1.drop(df_2_1.tail(10).index, inplace = True)
df_2_1: pd.DataFrame  = df_2_1.rolling(MOVING_AVERAGE_N).mean()
df_2_1: pd.DataFrame = df_2_1.dropna()
# ax = df_2_1.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 1")

df_2_2: pd.DataFrame = pd.read_csv(DATA_PATH2_2)
df_2_2: pd.DataFrame = df_2_2[df_2_2.action == "ReceivedResponse"]
df_2_2: pd.DataFrame = df_2_2["latency"].apply(lambda x: x*0.001)
df_2_2.drop(df_2_2.tail(10).index, inplace = True)
df_2_2: pd.DataFrame  = df_2_2.rolling(MOVING_AVERAGE_N).mean()
df_2_2: pd.DataFrame = df_2_2.dropna()
# ax = df_2_2.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 2")

df_2_3: pd.DataFrame = pd.read_csv(DATA_PATH2_3)
df_2_3: pd.DataFrame = df_2_3[df_2_3.action == "ReceivedResponse"]
df_2_3: pd.DataFrame = df_2_3["latency"].apply(lambda x: x*0.001)
df_2_3.drop(df_2_3.tail(10).index, inplace = True)
df_2_3: pd.DataFrame  = df_2_3.rolling(MOVING_AVERAGE_N).mean()
df_2_3: pd.DataFrame = df_2_3.dropna()
# ax = df_2_3.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 3")
# Out:
# Finished benchmark run 1
# Finished benchmark run 2
# Finished benchmark run 3

# %%
### 3 SHARDS
df_3_1: pd.DataFrame = pd.read_csv(DATA_PATH3_1)
df_3_1: pd.DataFrame = df_3_1[df_3_1.action == "ReceivedResponse"]
df_3_1: pd.DataFrame = df_3_1["latency"].apply(lambda x: x*0.001)
df_3_1.drop(df_3_1.tail(10).index, inplace = True)
df_3_1: pd.DataFrame  = df_3_1.rolling(MOVING_AVERAGE_N).mean()
df_3_1: pd.DataFrame = df_3_1.dropna()
# ax = df_3_1.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 1")

df_3_2: pd.DataFrame = pd.read_csv(DATA_PATH3_2)
df_3_2: pd.DataFrame = df_3_2[df_3_2.action == "ReceivedResponse"]
df_3_2: pd.DataFrame = df_3_2["latency"].apply(lambda x: x*0.001)
df_3_2.drop(df_3_2.tail(10).index, inplace = True)
df_3_2: pd.DataFrame  = df_3_2.rolling(MOVING_AVERAGE_N).mean()
df_3_2: pd.DataFrame = df_3_2.dropna()
# ax = df_3_2.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 2")

df_3_3: pd.DataFrame = pd.read_csv(DATA_PATH3_3)
df_3_3: pd.DataFrame = df_3_3[df_3_3.action == "ReceivedResponse"]
df_3_3: pd.DataFrame = df_3_3["latency"].apply(lambda x: x*0.001)
df_3_3.drop(df_3_3.tail(10).index, inplace = True)
df_3_3: pd.DataFrame  = df_3_3.rolling(MOVING_AVERAGE_N).mean()
df_3_3: pd.DataFrame = df_3_3.dropna()
# ax = df_3_3.plot(x=range(140),xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Process 0's Latency Moving Average", label="No Shards")
# ax.plot()
print("Finished benchmark run 3")
# Out:
# Finished benchmark run 1
# Finished benchmark run 2
# Finished benchmark run 3

# %%
"""
Procudes a plot for 2 and 3 shards (average from 3 experiments)
Comment out the "all sharding scenarios" code block below, to see this plot.
"""
plt.clf()
# 2 Shards
newSer2 = df_2_1.add(df_2_2).add(df_2_3)
divSer2 = newSer2/3
divSer2 = divSer2.dropna()
ax = divSer2.plot(xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Average Latency (3 benchmark runs)")

# 3 Shards
newSer3 = df_3_1.add(df_3_2).add(df_3_3)
divSer3 = newSer3/3
divSer3 = divSer3.dropna()
divSer3.plot(ax=ax)

plt.legend((["2 Shards", "3 Shards"]),loc='lower right')
all_data: pd.DataFrame = pd.read_csv(DATA_PATH2_2)
all_data: pd.DataFrame = all_data[all_data.action == "CreatedNewProcesses"]
indexes = all_data.index.values
print(indexes)
plt.xticks(indexes[:25:4], range(0,121,20)) # Written by hand
plt.show()
# Out:
# [     11   71346  162781  257874  353291  447750  543777  637549  727423
#   824046  918219 1012060 1106934 1201895 1296557 1390947 1486262 1579966
#  1672653 1767167 1862821 1956191 2045457 2133909 2223367 2310803]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
Procudes a plot for all sharding scenarios (average from 3 experiments)
"""
plt.clf()

# No Shards
newSer0 = df_0_1.add(df_0_2).add(df_0_3)
newSer0 = newSer0/3
newSer0 = newSer0.dropna()
ax = newSer0.plot(xlabel= "Total Number of Client Processes", ylabel="Latency (ms)",title="Average Latency (3 benchmark runs)", color = "green" )

# 2 Shards
newSer2 = df_2_1.add(df_2_2).add(df_2_3)
divSer2 = newSer2/3
divSer2 = divSer2.dropna()
divSer2.plot(ax=ax)

# 3 Shards
newSer3 = df_3_1.add(df_3_2).add(df_3_3)
divSer3 = newSer3/3
divSer3 = divSer3.dropna()
divSer3.plot(ax=ax)

plt.legend((["No Shards", "2 Shards", "3 Shards"]),loc='center right')
all_data: pd.DataFrame = pd.read_csv(DATA_PATH2_2)
all_data: pd.DataFrame = all_data[all_data.action == "CreatedNewProcesses"]
indexes = all_data.index.values
print(indexes)
plt.xticks(indexes[:25:4], range(0,121,20)) # Written by hand
plt.show()
# Out:
# [     11   71346  162781  257874  353291  447750  543777  637549  727423
#   824046  918219 1012060 1106934 1201895 1296557 1390947 1486262 1579966
#  1672653 1767167 1862821 1956191 2045457 2133909 2223367 2310803]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
